# %% [markdown]
# Simulated Patient

# %%
# !unzip aibi-dhi-simulator.zip
# Out:
# Archive:  aibi-dhi-simulator.zip
#    creating: aibi-dhi-simulator/.git/
#   inflating: aibi-dhi-simulator/.git/config
#   inflating: aibi-dhi-simulator/.git/description
#  extracting: aibi-dhi-simulator/.git/HEAD
#    creating: aibi-dhi-simulator/.git/hooks/
#   inflating: aibi-dhi-simulator/.git/hooks/applypatch-msg.sample
#   inflating: aibi-dhi-simulator/.git/hooks/commit-msg.sample
#   inflating: aibi-dhi-simulator/.git/hooks/fsmonitor-watchman.sample
#   inflating: aibi-dhi-simulator/.git/hooks/post-update.sample
#   inflating: aibi-dhi-simulator/.git/hooks/pre-applypatch.sample
#   inflating: aibi-dhi-simulator/.git/hooks/pre-commit.sample
#   inflating: aibi-dhi-simulator/.git/hooks/pre-merge-commit.sample
#   inflating: aibi-dhi-simulator/.git/hooks/prepare-commit-msg.sample
#   inflating: aibi-dhi-simulator/.git/hooks/pre-push.sample
#   inflating: aibi-dhi-simulator/.git/hooks/pre-rebase.sample
#   inflating: aibi-dhi-simulator/.git/hooks/pre-receive.sample
#   inflating: aibi-dhi-simulator/.git/hooks/update.sample
#   inflating: aibi-dhi-simulator/.git/index
#    creating: aibi-dhi-simulator/.git/info/
#   inflating: aibi-dhi-simulator/.git/info/exclude
#    creating: aibi-dhi-simulator/.git/logs/
#   inflating: aibi-dhi-simulator/.git/logs/HEAD
#    creating: aibi-dhi-simulator/.git/logs/refs/
#    creating: aibi-dhi-simulator/.git/logs/refs/heads/
#   inflating: aibi-dhi-simulator/.git/logs/refs/heads/master
#    creating: aibi-dhi-simulator/.git/logs/refs/remotes/
#    creating: aibi-dhi-simulator/.git/logs/refs/remotes/origin/
#   inflating: aibi-dhi-simulator/.git/logs/refs/remotes/origin/HEAD
#    creating: aibi-dhi-simulator/.git/objects/
#    creating: aibi-dhi-simulator/.git/objects/info/
#    creating: aibi-dhi-simulator/.git/objects/pack/
#   inflating: aibi-dhi-simulator/.git/objects/pack/pack-67da044caf5c8ba7916f02c311c215f8b370cc6c.idx
#   inflating: aibi-dhi-simulator/.git/objects/pack/pack-67da044caf5c8ba7916f02c311c215f8b370cc6c.pack
#   inflating: aibi-dhi-simulator/.git/packed-refs
#    creating: aibi-dhi-simulator/.git/refs/
#    creating: aibi-dhi-simulator/.git/refs/heads/
#  extracting: aibi-dhi-simulator/.git/refs/heads/master
#    creating: aibi-dhi-simulator/.git/refs/remotes/
#    creating: aibi-dhi-simulator/.git/refs/remotes/origin/
#  extracting: aibi-dhi-simulator/.git/refs/remotes/origin/HEAD
#    creating: aibi-dhi-simulator/.git/refs/tags/
#   inflating: aibi-dhi-simulator/.gitignore
#   inflating: aibi-dhi-simulator/Dockerfile
#   inflating: aibi-dhi-simulator/environment.yml
#    creating: aibi-dhi-simulator/environment/
#  extracting: aibi-dhi-simulator/environment/__init__.py
#    creating: aibi-dhi-simulator/environment/__pycache__/
#   inflating: aibi-dhi-simulator/environment/__pycache__/__init__.cpython-311.pyc
#   inflating: aibi-dhi-simulator/environment/__pycache__/fogg_behavioural_model.cpython-311.pyc
#   inflating: aibi-dhi-simulator/environment/fogg_behavioural_model.py
#   inflating: aibi-dhi-simulator/experiments.ipynb
#   inflating: aibi-dhi-simulator/README.md
#   inflating: aibi-dhi-simulator/requirements.txt
#    creating: aibi-dhi-simulator/results/
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run0.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run1.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run10.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run11.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run12.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run13.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run14.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run15.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run16.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run17.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run18.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run19.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run2.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run20.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run21.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run22.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run23.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run24.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run25.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run26.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run27.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run28.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run29.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run3.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run30.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run31.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run32.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run33.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run34.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run35.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run36.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run37.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run38.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run39.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run4.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run40.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run41.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run42.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run43.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run44.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run45.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run46.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run47.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run48.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run49.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run5.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run6.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run7.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run8.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_a2c_run9.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run0.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run1.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run10.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run11.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run12.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run13.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run14.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run15.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run16.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run17.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run18.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run19.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run2.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run20.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run21.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run22.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run23.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run24.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run25.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run26.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run27.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run28.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run29.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run3.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run30.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run31.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run32.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run33.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run34.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run35.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run36.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run37.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run38.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run39.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run4.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run40.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run41.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run42.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run43.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run44.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run45.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run46.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run47.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run48.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run49.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run5.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run6.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run7.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run8.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_adaptive_sup3_run9.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run0.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run1.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run10.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run11.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run12.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run13.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run14.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run15.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run16.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run17.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run18.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run19.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run2.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run20.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run21.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run22.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run23.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run24.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run25.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run26.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run27.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run28.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run29.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run3.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run30.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run31.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run32.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run33.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run34.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run35.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run36.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run37.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run38.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run39.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run4.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run40.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run41.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run42.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run43.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run44.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run45.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run46.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run47.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run48.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run49.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run5.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run6.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run7.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run8.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_dqn_run9.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run0.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run1.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run10.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run11.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run12.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run13.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run14.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run15.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run16.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run17.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run18.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run19.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run2.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run20.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run21.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run22.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run23.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run24.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run25.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run26.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run27.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run28.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run29.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run3.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run30.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run31.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run32.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run33.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run34.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run35.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run36.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run37.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run38.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run39.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run4.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run40.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run41.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run42.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run43.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run44.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run45.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run46.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run47.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run48.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run49.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run5.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run6.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run7.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run8.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_h_run9.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run0.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run1.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run10.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run11.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run12.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run13.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run14.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run15.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run16.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run17.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run18.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run19.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run2.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run20.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run21.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run22.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run23.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run24.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run25.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run26.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run27.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run28.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run29.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run3.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run30.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run31.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run32.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run33.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run34.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run35.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run36.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run37.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run38.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run39.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run4.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run40.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run41.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run42.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run43.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run44.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run45.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run46.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run47.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run48.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run49.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run5.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run6.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run7.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run8.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_ppo_run9.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run0.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run1.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run10.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run11.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run12.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run13.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run14.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run15.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run16.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run17.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run18.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run19.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run2.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run20.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run21.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run22.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run23.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run24.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run25.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run26.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run27.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run28.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run29.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run3.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run30.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run31.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run32.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run33.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run34.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run35.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run36.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run37.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run38.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run39.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run4.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run40.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run41.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run42.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run43.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run44.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run45.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run46.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run47.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run48.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run49.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run5.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run6.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run7.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run8.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_random_run9.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run0.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run1.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run10.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run11.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run12.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run13.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run14.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run15.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run16.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run17.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run18.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run19.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run2.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run20.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run21.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run22.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run23.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run24.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run25.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run26.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run27.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run28.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run29.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run3.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run30.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run31.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run32.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run33.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run34.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run35.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run36.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run37.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run38.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run39.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run4.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run40.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run41.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run42.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run43.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run44.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run45.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run46.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run47.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run48.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run49.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run5.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run6.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run7.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run8.csv
#   inflating: aibi-dhi-simulator/results/patient1_stable_static_sup3_run9.csv

# %%
# !pip install -r aibi-dhi-simulator/requirements.txt
# Out:
# Collecting gymnasium (from -r aibi-dhi-simulator/requirements.txt (line 1))
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r aibi-dhi-simulator/requirements.txt (line 2)) (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r aibi-dhi-simulator/requirements.txt (line 3)) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from -r aibi-dhi-simulator/requirements.txt (line 4)) (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from -r aibi-dhi-simulator/requirements.txt (line 6)) (1.2.2)
# Collecting stable-baselines3 (from -r aibi-dhi-simulator/requirements.txt (line 7))
#   Downloading stable_baselines3-2.3.2-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium->-r aibi-dhi-simulator/requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium->-r aibi-dhi-simulator/requirements.txt (line 1)) (4.11.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium->-r aibi-dhi-simulator/requirements.txt (line 1))
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->-r aibi-dhi-simulator/requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r aibi-dhi-simulator/requirements.txt (line 2)) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r aibi-dhi-simulator/requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r aibi-dhi-simulator/requirements.txt (line 4)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r aibi-dhi-simulator/requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r aibi-dhi-simulator/requirements.txt (line 4)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r aibi-dhi-simulator/requirements.txt (line 4)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r aibi-dhi-simulator/requirements.txt (line 4)) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r aibi-dhi-simulator/requirements.txt (line 4)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r aibi-dhi-simulator/requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r aibi-dhi-simulator/requirements.txt (line 6)) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r aibi-dhi-simulator/requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r aibi-dhi-simulator/requirements.txt (line 6)) (3.5.0)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7)) (2.3.0+cu121)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->-r aibi-dhi-simulator/requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7)) (3.14.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7)) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7)) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7))
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7))
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7))
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7))
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7))
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7))
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7))
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7))
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7))
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7))
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7))
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7)) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7))
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 29.6 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7)) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3->-r aibi-dhi-simulator/requirements.txt (line 7)) (1.3.0)
# Installing collected packages: farama-notifications, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, gymnasium, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable-baselines3
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 stable-baselines3-2.3.2

# %%
import pandas as pd
import numpy as np
import os

from textwrap import wrap
from matplotlib import pyplot as plt
from stable_baselines3 import PPO, A2C, DQN
from sklearn.ensemble import RandomForestClassifier

# %%
from aibi_dhi_simulator.environment.fogg_behavioural_model import Patient

# %%
updated_every_day = 24
week = 7 * updated_every_day

# %%
eight_weeks = week * 8
five_weeks = week * 5

# %%
# Basic stable condition
condition = 'stable'
habituation = False
time_preference_update_step = 9999999999999999 #very high e.g. 9999999999 to make it outside of the intervention time...effectively no preference shift

# Other options (not considered in the AIBI project):
# condition = 'habituated'
# habituation=True
# time_preference_update_step= 9999999999999999

# condition = 'changed_preference'
# habituation=False
# time_preference_update_step= five_weeks

# condition = 'habituated_changed_preference'
# habituation=True
# time_preference_update_step= five_weeks

# %%
# 500 runs in the paper
runs = 500

# %%
results_directory = 'results'
if not os.path.exists(results_directory):
    os.makedirs(results_directory)

# %% [markdown]
# # No interverntion

# %%
sleep_list = []
positive_list = []

for run in range(0, runs):

    # Change patient profile
    env1 = Patient(behaviour_threshold=20, habituation=habituation, time_preference_update_step=time_preference_update_step, patient_profile=0 )
    action = 0
    for i in  range(eight_weeks):

        observation, reward, done, _, info = env1.step(action)
        action = 0


    sleep_list.append(env1.h_slept)
    positive_list.append(env1.h_positive)

fig = plt.figure( figsize=(8, 5))
plt.plot(np.nanmean(sleep_list, axis=0), label='Hours slept', color ='r')
plt.plot(np.mean(positive_list, axis=0), label='Hours in positive mood')
plt.ylabel('Hours ')
plt.xlabel('Intevention Days')
plt.legend()
plt.show()

# %% [markdown]
# # Intervention

# %%
def intervention(method, runs, name, condition):
    rr_random_list = []
    not_random_list = []
    sleep_list = []
    positive_list = []
    performed = 0
    for run in range(0, runs):

        # Change patient profile
        env1 = Patient(behaviour_threshold=20,habituation=habituation, time_preference_update_step=time_preference_update_step, patient_profile=0)
        env1 = method(env1)
        if sum(env1.num_performed):
            performed += 1
        df = pd.DataFrame()
        df['response_ratio'] = env1.rr
        df['activity performed'] = env1.num_performed
        df['notifications'] = env1.num_notified
        df['sleep'] = env1.h_slept
        df['positive'] = env1.h_positive
        df['non_stationary'] = env1.h_nonstationary

        df.to_csv("{0}/patient1_{1}_{2}_run{3}.csv".format(results_directory, condition, name, run))
        rr_random_list.append(df.response_ratio)
        not_random_list.append(df.notifications)
        sleep_list.append(df.sleep)
        positive_list.append(df.positive)


    print("This figures include runs in which no prompt resulted in the activity being performed")
    print("{0} out of {1} resulted in activity being performed ".format(performed, runs))
    fig = plt.figure( figsize=(8, 5))
    plt.plot(np.nanmean(np.array(sleep_list), axis=0), label='Hours slept', color ='r')
    plt.plot(np.mean(positive_list, axis=0), label='Hours in positive mood')
    plt.ylabel('Hours ')
    plt.xlabel('Intevention Days')
    plt.legend()
    plt.show()

    fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, sharey=False, figsize=(10, 8))
    ax1.plot(np.nanmean(rr_random_list, axis=0), label='response ratio', color ='r')
    ax2.plot(np.nanmean(not_random_list, axis=0), label='num of notifications')
    ax2.set_xlabel('Intervention days')
    ax2.set_ylabel('No. of notifications')
    ax1.set_ylabel('Response ratio')
    plt.show()
    return sleep_list, positive_list, rr_random_list, not_random_list

# %% [markdown]
# ## Heuristic
#
# Notify every hour except in night and when the patient is alseep

# %%
def always_notify(env1, intervention_legth=eight_weeks):

    action = 0
    for i in  range(intervention_legth):

        observation, _, _, _, _ = env1.step(action)
        if observation[9] == 3 or observation[3] ==1:
            action = 0
        else:
            action = 1

    return env1

# %%
sleep_listh, positive_listh, rr_h_list, not_h_list = intervention(always_notify, runs, 'h', condition)
# Out:
# This figures include runs in which no prompt resulted in the activity being performed
# 354 out of 500 resulted in activity being performed

# %% [markdown]
# ## Random
# Randomly sample during the day skip the nights

# %%
def random_notification(env1, intervention_legth=eight_weeks):

    action = 0
    for i in  range(intervention_legth):

        observation, _, _, _, _ = env1.step(action)
        if observation[9] ==3:
            action = 0
        else:
            action = env1.action_space.sample()

    return env1

# %%
# %time _ = intervention(random_notification, runs, 'random', condition)
# Out:
# This figures include runs in which no prompt resulted in the activity being performed
# 400 out of 500 resulted in activity being performed
# CPU times: user 38.7 s, sys: 452 ms, total: 39.1 s
# Wall time: 44.1 s

# %%
def get_rr_and_notification(name, runs, condition):

    rr, noti = [],[]
    failed = 0
    for run in range(runs):
        df = pd.read_csv("{0}/patient1_{1}_{2}_run{3}.csv".format(results_directory,condition, name, run))
        a_performed = sum(df['activity performed'].values)
        if a_performed > 0: # activity performed at least once in the course of the intervention
            rr.append(df.response_ratio)
            noti.append(df.notifications)
        else:
            failed = failed +1
    print(" {0} out of {1} runs had no activity performed throughout the full intervention.".format(failed, runs))
    return rr, noti, failed

# %%
rr_random_list, not_random_list, fppo = get_rr_and_notification('random', runs, condition)
# Out:
#  100 out of 500 runs had no activity performed throughout the full intervention.

# %% [markdown]
# ## Supervised Learning
#
# ### Static model

# %%
def supervised_after_three_weeks(env1):

    three_weeks = 24 * 7 * 3
    env1 = always_notify(env1, intervention_legth=three_weeks)
    clf = RandomForestClassifier(class_weight='balanced')
    clf.fit(env1.observation_list, env1.activity_performed)
    remaining_time = eight_weeks - three_weeks
    observation = env1._get_current_state()
    for i in range(remaining_time):
        # applying supervised model
        action = clf.predict(np.array([observation]))[0]
        observation, _, _, _, _ = env1.step(action)

    return env1

# %%
# %time _ = intervention(supervised_after_three_weeks,runs , 'static_sup3', condition)
# Out:
# This figures include runs in which no prompt resulted in the activity being performed
# 237 out of 500 resulted in activity being performed
# CPU times: user 44min 58s, sys: 1min 7s, total: 46min 6s
# Wall time: 46min 5s

# %% [markdown]
# ### Adaptive model

# %%
def supervised_adaptive_after_three_weeks(env1):

    three_weeks = 24*7*3
    env1 = always_notify(env1, intervention_legth=three_weeks)
    clf = RandomForestClassifier(class_weight='balanced')
    clf.fit(env1.observation_list, env1.activity_performed)
    remaining_time = eight_weeks - three_weeks
    observation = env1._get_current_state()
    samples = len(env1.observation_list)
    for i in range(remaining_time):
        # applying supervised model
        action = clf.predict(np.array([observation]))[0]
        observation, _, _, _, _ = env1.step(action)
        if len(env1.observation_list)> samples: # retrain when new samples are provided
            clf = RandomForestClassifier(class_weight='balanced')
            clf.fit(env1.observation_list, env1.activity_performed)
            samples = len(env1.observation_list)


    return env1

# %%
# %time _ = intervention(supervised_adaptive_after_three_weeks, runs, 'adaptive_sup3', condition)
# Out:
# This figures include runs in which no prompt resulted in the activity being performed
# 248 out of 500 resulted in activity being performed
# CPU times: user 53min 32s, sys: 1min 3s, total: 54min 36s
# Wall time: 54min 42s

# %% [markdown]
# ### How many times supervised training faild?

# %%
rr_rf3_list, not_rf3_list, frf3 = get_rr_and_notification('static_sup3', runs, condition)
# Out:
#  263 out of 500 runs had no activity performed throughout the full intervention.

# %%
rr_rf3a_list, not_rf3a_list, frf3a = get_rr_and_notification('adaptive_sup3', runs, condition)
# Out:
#  252 out of 500 runs had no activity performed throughout the full intervention.

# %% [markdown]
# ## Deep Q Network

# %%
def dqn(env1):
    model = DQN("MlpPolicy", env1, verbose=0, learning_starts=updated_every_day)
    model.learn(total_timesteps=eight_weeks)
    return env1

# %%
# %time _= intervention(dqn, runs, 'dqn', condition)
# Out:
# This figures include runs in which no prompt resulted in the activity being performed
# 327 out of 500 resulted in activity being performed
# CPU times: user 24min 9s, sys: 9.73 s, total: 24min 18s
# Wall time: 24min 35s

# %%
rr_dqn_list, not_dqn_list, fdqn = get_rr_and_notification('dqn', runs, condition)
# Out:
#  173 out of 500 runs had no activity performed throughout the full intervention.

# %% [markdown]
# ## Proximal Policy Optimisation

# %%
def ppo(env1):
    model = PPO("MlpPolicy", env1, verbose=0, n_steps=updated_every_day, batch_size=updated_every_day)
    model.learn(total_timesteps=eight_weeks)
    return env1

# %%
# %time _= intervention(ppo, runs, 'ppo', condition)
# Out:
# This figures include runs in which no prompt resulted in the activity being performed
# 326 out of 500 resulted in activity being performed
# CPU times: user 45min 18s, sys: 14.4 s, total: 45min 32s
# Wall time: 46min 3s

# %%
rr_ppo_list, not_ppo_list, fppo = get_rr_and_notification('ppo', runs, condition)
# Out:
#  174 out of 500 runs had no activity performed throughout the full intervention.

# %% [markdown]
# ## Advantage Actor Critic

# %%
def a2c(env1):
    model = A2C("MlpPolicy", env1, verbose=0, n_steps=updated_every_day)
    model.learn(total_timesteps=eight_weeks)
    return env1

# %%
# %time _ = intervention(a2c, runs, 'a2c', condition)
# Out:
# This figures include runs in which no prompt resulted in the activity being performed
# 364 out of 500 resulted in activity being performed
# CPU times: user 20min 17s, sys: 4.08 s, total: 20min 21s
# Wall time: 20min 38s

# %%
rr_a2c_list, not_a2c_list, fppo = get_rr_and_notification('a2c', runs, condition)
# Out:
#  136 out of 500 runs had no activity performed throughout the full intervention.

# %% [markdown]
# ## Comparison between prompt learning stategies

# %%
fig, (ax1,ax2) = plt.subplots(2, 1, sharex=True, sharey=False, figsize=(10,10))
ax1.plot(np.nanmean(rr_random_list, axis=0), label='Random')
ax1.plot(np.nanmean(rr_rf3_list, axis=0), label='RF static')
ax1.plot(np.nanmean(rr_rf3a_list, axis=0), label='RF adaptive')
ax1.plot(np.nanmean(rr_dqn_list, axis=0), label='DQN')
ax1.plot(np.nanmean(rr_ppo_list, axis=0), label='PPO')
ax1.plot(np.nanmean(rr_a2c_list, axis=0), label='A2C')


ax2.plot(np.nanmean(not_random_list, axis=0), label='Random')
ax2.plot(np.nanmean(not_rf3_list, axis=0), label='RF static')
ax2.plot(np.nanmean(not_rf3a_list, axis=0), label='RF adaptive')
ax2.plot(np.nanmean(not_dqn_list, axis=0), label='DQN')
ax2.plot(np.nanmean(not_ppo_list, axis=0), label='PPO')
ax2.plot(np.nanmean(not_a2c_list, axis=0), label='A2C')
ax2.plot(np.ones(len(np.mean(not_random_list, axis=0))) +2, label ='Preferred number of notifications a day')

ax2.set_xlabel('Intervention Days', fontsize=16)
ax2.set_ylabel('\n'.join(wrap('Numbers of notifications', 20)), fontsize=16)
ax1.set_ylabel('\n'.join(wrap('Activity performed to prompt ratio', 20)) )
# ax3.set_ylabel( '\n'.join(wrap('Hours slept', 20)) )
# plt.ylim(0, 0.95)
ax2.legend(fontsize=13)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
